# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
url = 'https://docs.google.com/spreadsheets/d/1ajCkZB1C1fGvYSRRKqZ8JT_MHth5c_8w/edit?usp=drive_link&ouid=111930618054542411595&rtpof=true&sd=true'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]
df_GENSHIN = pd.read_excel(url)
df_GENSHIN.head(10)
# Out:
#   CHARACTER-NAME  RARITY     REGION   VISION WEAPON_TYPE          MODEL  \
# 0         Albedo       5  Mondstadt      Geo       Sword    Male Medium
# 1      Alhaitham       5     Sumeru   Dendro       Sword      Male Tall
# 2           Aloy       5        NaN     Cryo         Bow  Female Medium
# 3          Amber       4  Mondstadt     Pyro         Bow  Female Medium
# 4   Arataki Itto       5    Inazuma      Geo    Claymore      Male Tall
# 5         Baizhu       5      Liyue   Dendro    Catalyst      Male Tall
# 6        Barbara       4  Mondstadt    Hydro    Catalyst  Female Medium
# 7         Beidou       4      Liyue  Electro    Claymore    Female Tall
# 8        Bennett       4  Mondstadt     Pyro       Sword    Male Medium
# 9        Candace       4     Sumeru    Hydro     Polearm    Female Tall
#
#     BIRTHDAY       CONSTELLATION RELEASE_DATE  LIMITED         AFFILICATION  \
# 0 2022-09-13  Princeps Cretaceus   2020-12-23      1.0  Knights of Favonius
# 1 2023-02-11       Vultur Volans   2023-01-18      1.0     Sumeru Akademiya
# 2 2022-04-04         Nora Fortis   2021-09-01      NaN    Wandering Heroine
# 3 2022-08-10               Lepus   2020-09-28      0.0  Knights of Favonius
# 4 2022-06-01    Taurus Iracundus   2021-12-14      1.0         Arataki Gang
# 5 2023-04-25           Lagenaria   2023-05-02      1.0        Bubu Pharmacy
# 6 2022-07-05              Crater   2020-09-28      0.0   Church of Favonius
# 7 2022-02-14         Victor Mare   2020-09-28      0.0             The Crux
# 8 2029-02-01      Rota Calamitas   2020-09-28      0.0   Adventurers' Guild
# 9 2022-05-03      Sagitta Scutum   2022-09-28      0.0         Aaru Village
#
#    HP_90_90  ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE  \
# 0     13226        251        876         0.950           0.60
# 1     13348        373        781         0.920           0.76
# 2     10899        234        676         0.020           0.10
# 3      9461        223        601         0.900           0.40
# 4     12858        327        959         0.880           0.71
# 5     13348        192        499         0.860           0.89
# 6      9787        159        669         0.840           0.58
# 7     13050        225        648         0.820           0.13
# 8     12397        191        771         0.868           0.95
# 9     10874        212        682         0.100           0.15
#
#            ASCENSION PRI SKILL
# 0      Geo DMG Bonus         Q
# 1   Dendro DMG Bonus         E
# 2     Cryo DMG Bonus         Q
# 3                ATK         T
# 4          CRIT Rate         Q
# 5                 HP         E
# 6                 HP         E
# 7  Electro DMG Bonus         Q
# 8    Energy Recharge         Q
# 9                 HP         Q

# %% [markdown]
# # Mục mới

# %% [markdown]
# #**CLEAR DATA**

# %%
df_GENSHIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CHARACTER-NAME  74 non-null     object
#  1   RARITY          74 non-null     int64
#  2   REGION          73 non-null     object
#  3   VISION          74 non-null     object
#  4   WEAPON_TYPE     74 non-null     object
#  5   MODEL           74 non-null     object
#  6   BIRTHDAY        74 non-null     datetime64[ns]
#  7   CONSTELLATION   74 non-null     object
#  8   RELEASE_DATE    74 non-null     datetime64[ns]
#  9   LIMITED         73 non-null     float64
#  10  AFFILICATION    73 non-null     object
#  11  HP_90_90        74 non-null     int64
#  12  ATK_90_90       74 non-null     int64
#  13  DEF_90_90       74 non-null     int64
#  14  LEVEL OF USE    74 non-null     float64
#  15  LEVEL OF LOVE   74 non-null     float64
#  16  ASCENSION       74 non-null     object
#  17  PRI SKILL       74 non-null     object
# dtypes: datetime64[ns](2), float64(3), int64(4), object(9)
# memory usage: 10.5+ KB

# %%
#XÓA CỘT LIMITED
df_GENSHIN.drop('LIMITED', axis=1, inplace=True)

# %%
# Thay thế dữ liệu NA bằng giá trị 'unknown'
df_GENSHIN['REGION'].fillna('Unknown', inplace=True)
df_GENSHIN
# Out:
#    CHARACTER-NAME  RARITY     REGION  VISION WEAPON_TYPE          MODEL  \
# 0          Albedo       5  Mondstadt     Geo       Sword    Male Medium
# 1       Alhaitham       5     Sumeru  Dendro       Sword      Male Tall
# 2            Aloy       5    Unknown    Cryo         Bow  Female Medium
# 3           Amber       4  Mondstadt    Pyro         Bow  Female Medium
# 4    Arataki Itto       5    Inazuma     Geo    Claymore      Male Tall
# ..            ...     ...        ...     ...         ...            ...
# 69         Yaoyao       4      Liyue  Dendro     Polearm   Female Short
# 70          Yelan       5      Liyue   Hydro         Bow    Female Tall
# 71        Yoimiya       5    Inazuma    Pyro         Bow  Female Medium
# 72        Yun Jin       4      Liyue     Geo     Polearm  Female Medium
# 73        Zhongli       5      Liyue     Geo     Polearm      Male Tall
#
#      BIRTHDAY       CONSTELLATION RELEASE_DATE                AFFILICATION  \
# 0  2022-09-13  Princeps Cretaceus   2020-12-23         Knights of Favonius
# 1  2023-02-11       Vultur Volans   2023-01-18            Sumeru Akademiya
# 2  2022-04-04         Nora Fortis   2021-09-01           Wandering Heroine
# 3  2022-08-10               Lepus   2020-09-28         Knights of Favonius
# 4  2022-06-01    Taurus Iracundus   2021-12-14                Arataki Gang
# ..        ...                 ...          ...                         ...
# 69 2023-03-06           Osmanthus   2023-01-18  Streetward Rambler's Abode
# 70 2022-04-20   Umbrabilis Orchis   2022-05-31           Yanshang Teahouse
# 71 2022-06-21   Carassius Auratus   2021-08-10        Naganohara Fireworks
# 72 2022-05-21       Opera Grandis   2022-01-05         Yun-Han Opera House
# 73 2022-12-31           Lapis Dei   2020-12-01                Liyue Harbor
#
#     HP_90_90  ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE  \
# 0      13226        251        876          0.95           0.60
# 1      13348        373        781          0.92           0.76
# 2      10899        234        676          0.02           0.10
# 3       9461        223        601          0.90           0.40
# 4      12858        327        959          0.88           0.71
# ..       ...        ...        ...           ...            ...
# 69     12288        212        750          0.64           0.49
# 70     14450        244        548          0.77           0.67
# 71     10164        323        615          0.24           0.59
# 72     10657        191        734          0.89           0.63
# 73     14695        251        738          0.90           0.90
#
#            ASCENSION PRI SKILL
# 0      Geo DMG Bonus         Q
# 1   Dendro DMG Bonus         E
# 2     Cryo DMG Bonus         Q
# 3                ATK         T
# 4          CRIT Rate         Q
# ..               ...       ...
# 69                HP         Q
# 70         CRIT Rate         Q
# 71         CRIT Rate         Q
# 72   Energy Recharge         Q
# 73     Geo DMG Bonus         E
#
# [74 rows x 17 columns]

# %%
# TÁCH CỘT MODEL THÀNH SEX VÀ MODEL
df_GENSHIN[['SEX','MODEL']] = df_GENSHIN['MODEL'].str.split(' ', expand = True)
df_GENSHIN.head(10)
# Out:
#   CHARACTER-NAME  RARITY     REGION   VISION WEAPON_TYPE   MODEL   BIRTHDAY  \
# 0         Albedo       5  Mondstadt      Geo       Sword  Medium 2022-09-13
# 1      Alhaitham       5     Sumeru   Dendro       Sword    Tall 2023-02-11
# 2           Aloy       5    Unknown     Cryo         Bow  Medium 2022-04-04
# 3          Amber       4  Mondstadt     Pyro         Bow  Medium 2022-08-10
# 4   Arataki Itto       5    Inazuma      Geo    Claymore    Tall 2022-06-01
# 5         Baizhu       5      Liyue   Dendro    Catalyst    Tall 2023-04-25
# 6        Barbara       4  Mondstadt    Hydro    Catalyst  Medium 2022-07-05
# 7         Beidou       4      Liyue  Electro    Claymore    Tall 2022-02-14
# 8        Bennett       4  Mondstadt     Pyro       Sword  Medium 2029-02-01
# 9        Candace       4     Sumeru    Hydro     Polearm    Tall 2022-05-03
#
#         CONSTELLATION RELEASE_DATE         AFFILICATION  HP_90_90  ATK_90_90  \
# 0  Princeps Cretaceus   2020-12-23  Knights of Favonius     13226        251
# 1       Vultur Volans   2023-01-18     Sumeru Akademiya     13348        373
# 2         Nora Fortis   2021-09-01    Wandering Heroine     10899        234
# 3               Lepus   2020-09-28  Knights of Favonius      9461        223
# 4    Taurus Iracundus   2021-12-14         Arataki Gang     12858        327
# 5           Lagenaria   2023-05-02        Bubu Pharmacy     13348        192
# 6              Crater   2020-09-28   Church of Favonius      9787        159
# 7         Victor Mare   2020-09-28             The Crux     13050        225
# 8      Rota Calamitas   2020-09-28   Adventurers' Guild     12397        191
# 9      Sagitta Scutum   2022-09-28         Aaru Village     10874        212
#
#    DEF_90_90  LEVEL OF USE  LEVEL OF LOVE          ASCENSION PRI SKILL     SEX
# 0        876         0.950           0.60      Geo DMG Bonus         Q    Male
# 1        781         0.920           0.76   Dendro DMG Bonus         E    Male
# 2        676         0.020           0.10     Cryo DMG Bonus         Q  Female
# 3        601         0.900           0.40                ATK         T  Female
# 4        959         0.880           0.71          CRIT Rate         Q    Male
# 5        499         0.860           0.89                 HP         E    Male
# 6        669         0.840           0.58                 HP         E  Female
# 7        648         0.820           0.13  Electro DMG Bonus         Q  Female
# 8        771         0.868           0.95    Energy Recharge         Q    Male
# 9        682         0.100           0.15                 HP         Q  Female

# %%
#DI CHUYỂN CỘT SEX TRƯỚC CỘT MODEL
#column_to_move = df_GENSHIN.pop("SEX")
df_GENSHIN.insert(5, "SEX", df_GENSHIN.pop("SEX"))
df_GENSHIN.head(10)
df_GENSHIN.to_excel('GENSHIN_FIXED.xlsx') #Tạo thành dataframe mới, dưới dây đều dùng nó

# %% [markdown]
# # **Thống kê mô tả GENSHIN_DATA**

# %%
url = 'https://docs.google.com/spreadsheets/d/1H9UT0x4AQ9dwMtIcYO9C0VaOE17YUOWd/edit?usp=sharing&ouid=111930618054542411595&rtpof=true&sd=true'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]
df_GENSHIN = pd.read_excel(url)
df_GENSHIN.head(10)
# Out:
#    Unnamed: 0 CHARACTER-NAME  RARITY     REGION   VISION WEAPON_TYPE     SEX  \
# 0           0         Albedo       5  Mondstadt      Geo       Sword    Male
# 1           1      Alhaitham       5     Sumeru   Dendro       Sword    Male
# 2           2           Aloy       5    Unknown     Cryo         Bow  Female
# 3           3          Amber       4  Mondstadt     Pyro         Bow  Female
# 4           4   Arataki Itto       5    Inazuma      Geo    Claymore    Male
# 5           5         Baizhu       5      Liyue   Dendro    Catalyst    Male
# 6           6        Barbara       4  Mondstadt    Hydro    Catalyst  Female
# 7           7         Beidou       4      Liyue  Electro    Claymore  Female
# 8           8        Bennett       4  Mondstadt     Pyro       Sword    Male
# 9           9        Candace       4     Sumeru    Hydro     Polearm  Female
#
#     MODEL   BIRTHDAY       CONSTELLATION RELEASE_DATE         AFFILICATION  \
# 0  Medium 2022-09-13  Princeps Cretaceus   2020-12-23  Knights of Favonius
# 1    Tall 2023-02-11       Vultur Volans   2023-01-18     Sumeru Akademiya
# 2  Medium 2022-04-04         Nora Fortis   2021-09-01    Wandering Heroine
# 3  Medium 2022-08-10               Lepus   2020-09-28  Knights of Favonius
# 4    Tall 2022-06-01    Taurus Iracundus   2021-12-14         Arataki Gang
# 5    Tall 2023-04-25           Lagenaria   2023-05-02        Bubu Pharmacy
# 6  Medium 2022-07-05              Crater   2020-09-28   Church of Favonius
# 7    Tall 2022-02-14         Victor Mare   2020-09-28             The Crux
# 8  Medium 2029-02-01      Rota Calamitas   2020-09-28   Adventurers' Guild
# 9    Tall 2022-05-03      Sagitta Scutum   2022-09-28         Aaru Village
#
#    HP_90_90  ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE  \
# 0     13226        251        876         0.950           0.60
# 1     13348        373        781         0.920           0.76
# 2     10899        234        676         0.020           0.10
# 3      9461        223        601         0.900           0.40
# 4     12858        327        959         0.880           0.71
# 5     13348        192        499         0.860           0.89
# 6      9787        159        669         0.840           0.58
# 7     13050        225        648         0.820           0.13
# 8     12397        191        771         0.868           0.95
# 9     10874        212        682         0.100           0.15
#
#            ASCENSION PRI SKILL
# 0      Geo DMG Bonus         Q
# 1   Dendro DMG Bonus         E
# 2     Cryo DMG Bonus         Q
# 3                ATK         T
# 4          CRIT Rate         Q
# 5                 HP         E
# 6                 HP         E
# 7  Electro DMG Bonus         Q
# 8    Energy Recharge         Q
# 9                 HP         Q

# %%
#Thống kê mô tả các biến định lượng trong dataframe
df_GENSHIN.describe()
# Out:
#        Unnamed: 0     RARITY                       BIRTHDAY  \
# count   74.000000  74.000000                             74
# mean    36.500000   4.500000  2022-11-04 01:37:17.837837824
# min      0.000000   4.000000            2022-01-09 00:00:00
# 25%     18.250000   4.000000            2022-05-28 06:00:00
# 50%     36.500000   4.500000            2022-09-03 12:00:00
# 75%     54.750000   5.000000            2023-01-02 06:00:00
# max     73.000000   5.000000            2029-02-01 00:00:00
# std     21.505813   0.503413                            NaN
#
#                         RELEASE_DATE      HP_90_90   ATK_90_90   DEF_90_90  \
# count                             74     74.000000   74.000000   74.000000
# mean   2021-11-19 09:24:19.459459584  11841.054054  258.513514  700.378378
# min              2020-09-28 00:00:00   9189.000000  159.000000  499.000000
# 25%              2020-09-28 00:00:00  10363.000000  223.000000  627.250000
# 50%              2021-09-01 00:00:00  12016.500000  241.500000  705.500000
# 75%              2022-10-10 00:00:00  13035.750000  306.250000  769.000000
# max              2023-12-07 00:00:00  15674.000000  399.000000  959.000000
# std                              NaN   1721.818964   56.415592   97.437258
#
#        LEVEL OF USE  LEVEL OF LOVE
# count     74.000000      74.000000
# mean       0.574014       0.602568
# min        0.020000       0.080000
# 25%        0.250000       0.412500
# 50%        0.670000       0.615000
# 75%        0.887500       0.865000
# max        0.999000       0.980000
# std        0.332296       0.269972

# %%
#Lọc ra nhân vật có HP mạnh nhất
df_GENSHIN_HP = df_GENSHIN.loc[df_GENSHIN["HP_90_90"] == df_GENSHIN["HP_90_90"].max()]
df_GENSHIN_HP
# Out:
#     Unnamed: 0 CHARACTER-NAME  RARITY  REGION VISION WEAPON_TYPE     SEX  \
# 14          14          Dehya       5  Sumeru   Pyro    Claymore  Female
#
#    MODEL   BIRTHDAY CONSTELLATION RELEASE_DATE  AFFILICATION  HP_90_90  \
# 14  Tall 2023-04-07    Mantichora   2023-03-01  The Eremites     15674
#
#     ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE ASCENSION PRI SKILL
# 14        265        627           0.1           0.37        HP         Q

# %%
#Lọc ra nhân vật có ATK mạnh nhất
df_GENSHIN_ATK = df_GENSHIN.loc[df_GENSHIN["ATK_90_90"] == df_GENSHIN["ATK_90_90"].max()]
df_GENSHIN_ATK
# Out:
#     Unnamed: 0  CHARACTER-NAME  RARITY   REGION VISION WEAPON_TYPE   SEX  \
# 30          30  Kamisato Ayato       5  Inazuma  Hydro       Sword  Male
#
#    MODEL   BIRTHDAY     CONSTELLATION RELEASE_DATE        AFFILICATION  \
# 30  Tall 2022-03-26  Cypressus Custos   2022-04-30  Yashiro Commission
#
#     HP_90_90  ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE ASCENSION  \
# 30     13715        399        769           0.9           0.94  CRIT DMG
#
#    PRI SKILL
# 30         T

# %%
#lọc ra nhân vật có DEF (phòng ngự) mạnh nhất
df_GENSHIN_DEF = df_GENSHIN.loc[df_GENSHIN["DEF_90_90"] == df_GENSHIN["DEF_90_90"].max()]
df_GENSHIN_DEF
# Out:
#    Unnamed: 0 CHARACTER-NAME  RARITY   REGION VISION WEAPON_TYPE   SEX MODEL  \
# 4           4   Arataki Itto       5  Inazuma    Geo    Claymore  Male  Tall
#
#     BIRTHDAY     CONSTELLATION RELEASE_DATE  AFFILICATION  HP_90_90  \
# 4 2022-06-01  Taurus Iracundus   2021-12-14  Arataki Gang     12858
#
#    ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE  ASCENSION PRI SKILL
# 4        327        959          0.88           0.71  CRIT Rate         Q

# %%
#Lọc ra nhân vật có mức độ sử dụng nhiều nhất
df_GENSHIN_USE = df_GENSHIN.loc[df_GENSHIN["LEVEL OF USE"] == df_GENSHIN["LEVEL OF USE"].max()]
df_GENSHIN_USE
# Out:
#     Unnamed: 0 CHARACTER-NAME  RARITY    REGION VISION WEAPON_TYPE   SEX  \
# 47          47    Neuvillette       5  Fontaine  Hydro    Catalyst  Male
#
#    MODEL   BIRTHDAY        CONSTELLATION RELEASE_DATE       AFFILICATION  \
# 47  Tall 2023-12-18  Leviathan Judicator   2023-09-27  Court of Fontaine
#
#     HP_90_90  ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE ASCENSION  \
# 47     14695        308        576         0.999           0.97  CRIT DMG
#
#    PRI SKILL
# 47         T

# %%
#Nhân vật có mức độ sử dụng ít nhất
df_GENSHIN_USE = df_GENSHIN.loc[df_GENSHIN["LEVEL OF USE"] == df_GENSHIN["LEVEL OF USE"].min()]
df_GENSHIN_USE
# Out:
#     Unnamed: 0 CHARACTER-NAME  RARITY   REGION VISION WEAPON_TYPE     SEX  \
# 2            2           Aloy       5  Unknown   Cryo         Bow  Female
# 68          68         Yanfei       4    Liyue   Pyro    Catalyst  Female
#
#      MODEL   BIRTHDAY    CONSTELLATION RELEASE_DATE              AFFILICATION  \
# 2   Medium 2022-04-04      Nora Fortis   2021-09-01         Wandering Heroine
# 68  Medium 2022-07-28  Bestia Iustitia   2021-04-28  Yanfei Legal Consultancy
#
#     HP_90_90  ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE  \
# 2      10899        234        676          0.02            0.1
# 68      9352        301        587          0.02            0.4
#
#          ASCENSION PRI SKILL
# 2   Cryo DMG Bonus         Q
# 68  Pyro DMG Bonus         T

# %%
#Lọc ra nhân vật được yêu thích nhất
df_GENSHIN_LOVE = df_GENSHIN.loc[df_GENSHIN["LEVEL OF LOVE"] == df_GENSHIN["LEVEL OF LOVE"].max()]
df_GENSHIN_LOVE
# Out:
#     Unnamed: 0 CHARACTER-NAME  RARITY   REGION   VISION WEAPON_TYPE     SEX  \
# 49          49  Raiden Shogun       5  Inazuma  Electro     Polearm  Female
#
#    MODEL   BIRTHDAY       CONSTELLATION RELEASE_DATE  AFFILICATION  HP_90_90  \
# 49  Tall 2022-06-26  Imperatrix Umbrosa   2021-09-01  Inazuma City     12907
#
#     ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE        ASCENSION  \
# 49        237        789         0.976           0.98  Energy Recharge
#
#    PRI SKILL
# 49         E

# %%
#Lọc ra nhân vật ít được yêu thích nhất
df_GENSHIN_LOVE = df_GENSHIN.loc[df_GENSHIN["LEVEL OF LOVE"] == df_GENSHIN["LEVEL OF LOVE"].min()]
df_GENSHIN_LOVE
# Out:
#     Unnamed: 0 CHARACTER-NAME  RARITY   REGION VISION WEAPON_TYPE   SEX MODEL  \
# 58          58          Thoma       4  Inazuma   Pyro     Polearm  Male  Tall
#
#      BIRTHDAY  CONSTELLATION RELEASE_DATE        AFFILICATION  HP_90_90  \
# 58 2022-01-09  Rubeum Scutum   2021-10-02  Yashiro Commission     10331
#
#     ATK_90_90  DEF_90_90  LEVEL OF USE  LEVEL OF LOVE ASCENSION PRI SKILL
# 58        202        751           0.9           0.08       ATK         Q

# %% [markdown]
# #**GROUPBY**

# %%
#GIỮA CỘT REGION - VISION, SEX, WEAPON_TYPE
df_GENSHIN_REGION_VSW = df_GENSHIN.groupby(['REGION'])[['VISION', 'WEAPON_TYPE', "SEX"]]
df_GENSHIN_REGION_VSW.describe()
# Out:
#           VISION                      WEAPON_TYPE                         SEX  \
#            count unique      top freq       count unique       top freq count
# REGION
# Fontaine       7      4     Cryo    3           7      4  Catalyst    3     7
# Inazuma       15      7  Electro    4          15      5     Sword    5    15
# Liyue         18      7     Cryo    4          18      5   Polearm    7    18
# Mondstadt     19      6     Cryo    5          19      5  Catalyst    5    19
# Snezhnaya      1      1    Hydro    1           1      1       Bow    1     1
# Sumeru        13      6   Dendro    5          13      5     Sword    3    13
# Unknown        1      1     Cryo    1           1      1       Bow    1     1
#
#
#           unique     top freq
# REGION
# Fontaine       2    Male    4
# Inazuma        2  Female    9
# Liyue          2  Female   13
# Mondstadt      2  Female   12
# Snezhnaya      1    Male    1
# Sumeru         2  Female    8
# Unknown        1  Female    1

# %%
df1 = df_GENSHIN.groupby(['VISION'])[["SEX"]]
df1.value_counts()
# Out:
# VISION   SEX
# Anemo    Female     5
#          Male       5
# Cryo     Female    10
#          Male       5
# Dendro   Female     4
#          Male       4
# Electro  Female     9
#          Male       2
# Geo      Male       4
#          Female     3
# Hydro    Female     7
#          Male       4
# Pyro     Female     8
#          Male       4
# Name: count, dtype: int64

# %%
df_GENSHIN_REGION_VSW = df_GENSHIN.groupby(['REGION'])[['VISION']]
df_GENSHIN_REGION_VSW.value_counts()
# Out:
# REGION     VISION
# Fontaine   Cryo       3
#            Hydro      2
#            Anemo      1
#            Pyro       1
# Inazuma    Electro    4
#            Anemo      3
#            Pyro       2
#            Hydro      2
#            Geo        2
#            Dendro     1
#            Cryo       1
# Liyue      Cryo       4
#            Pyro       4
#            Geo        3
#            Electro    2
#            Hydro      2
#            Dendro     2
#            Anemo      1
# Mondstadt  Cryo       5
#            Pyro       4
#            Electro    3
#            Anemo      3
#            Hydro      2
#            Geo        2
# Snezhnaya  Hydro      1
# Sumeru     Dendro     5
#            Anemo      2
#            Electro    2
#            Hydro      2
#            Pyro       1
#            Cryo       1
# Unknown    Cryo       1
# Name: count, dtype: int64

# %%
df1 = df_GENSHIN.groupby('SEX')['MODEL']
df1.value_counts()
# Out:
# SEX     MODEL
# Female  Medium    26
#         Tall      13
#         Short      7
# Male    Medium    16
#         Tall      12
# Name: count, dtype: int64

# %%
df_GENSHIN_WS = df_GENSHIN.groupby(['SEX'])['WEAPON_TYPE']
df_GENSHIN_WS.value_counts()
# Out:
# SEX     WEAPON_TYPE
# Female  Catalyst       11
#         Bow            10
#         Sword          10
#         Polearm         8
#         Claymore        7
# Male    Sword           7
#         Claymore        6
#         Bow             5
#         Catalyst        5
#         Polearm         5
# Name: count, dtype: int64

# %% [markdown]
# # **Vẽ Đồ thị tương tác thông qua việc liên kết với bokeh**

# %%
import bokeh.io
import bokeh.plotting

# %%
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, show
from matplotlib import pyplot as plt

# %%
numerical_variables = df_GENSHIN.select_dtypes(exclude='object')

# %%
#Tạo ma trận tương quan
import seaborn as sns

MTTQ = numerical_variables.corr()

sns.heatmap(MTTQ, annot=True,linewidths=30 )
plt.title('Ma trận tương quan giữa các biến ĐỊNH LƯỢNG')
plt.show()

# %%
sns.pairplot(df_GENSHIN)

# %%
from bokeh.io import output_file, show # dùng để chỉ định tên file HTML mà đồ thị sẽ được lưu vào khi xuất. Hàm show dùng để hiển thị đồ thị trong trình duyệt web hoặc lưu nó vào file
from bokeh.models import ColumnDataSource, FactorRange # Câu lệnh này nhập ColumnDataSource, một đối tượng cung cấp dữ liệu cho các glyphs trong Bokeh, và FactorRange, dùng để tạo ra phạm vi cho các biến phân loại (categorical variables) trên trục đồ thị.
from bokeh.transform import factor_cmap #bảng màu
from bokeh.layouts import row #Hàm này cho phép bạn sắp xếp các đối tượng đồ thị (plots) hoặc các widget cạnh nhau theo chiều ngang trong một hàng.
from bokeh.models.tools import HoverTool  #HoverTool được thêm vào để khi di chuột qua các cột, bạn sẽ thấy thông tin chi tiết về cột đó
# Dữ liệu
visions = ["Anemo", "Cryo", "Dendro", "Electro", "Geo", "Hydro", "Pyro"]
sexs = ["Female", "Male"]
factors = [(vision, sex) for vision in visions for sex in sexs ]

counts = [5, 5, 10, 5, 4, 4, 9, 2, 4, 3, 7, 4, 8, 4]


source = ColumnDataSource(data=dict(factors=factors, counts=counts))

p = figure(title="HÌNH 1: ĐỒ THỊ GIỚI TÍNH THEO NGUYÊN TỐ Ở MONSTALT", x_range=FactorRange(*factors),toolbar_location= "right")

p.vbar(x='factors', top='counts', width=0.9, source=source,
       line_color="white",
       fill_color=factor_cmap('factors', palette=["pink", "blue"], factors=sexs, start=1, end=2))

p.add_tools(HoverTool(tooltips=[("Vision, Sex", "@factors"), ("Count", "@counts")]))

p.y_range.start = 0
p.x_range.range_padding = 0.1 #Khoảng cách giữa đồ thị và trục tung
p.xaxis.major_label_orientation = 1 #độ nghiên của nhãn ở trục x "female và male"

show(p)
# Out:
#   <div id="e755a52f-343a-4bec-8592-1ad500045191" data-root-id="p1005" style="display: contents;"></div>

# %%
from bokeh.io import output_file, show # dùng để chỉ định tên file HTML mà đồ thị sẽ được lưu vào khi xuất. Hàm show dùng để hiển thị đồ thị trong trình duyệt web hoặc lưu nó vào file
from bokeh.models import ColumnDataSource, FactorRange # Câu lệnh này nhập ColumnDataSource, một đối tượng cung cấp dữ liệu cho các glyphs trong Bokeh, và FactorRange, dùng để tạo ra phạm vi cho các biến phân loại (categorical variables) trên trục đồ thị.
from bokeh.transform import factor_cmap #bảng màu
from bokeh.layouts import row #Hàm này cho phép bạn sắp xếp các đối tượng đồ thị (plots) hoặc các widget cạnh nhau theo chiều ngang trong một hàng.
from bokeh.models.tools import HoverTool  #HoverTool được thêm vào để khi di chuột qua các cột, bạn sẽ thấy thông tin chi tiết về cột đó
# Dữ liệu
model = ["Medium", "Tail", "Short"]
sexs = ["Female", "Male"]
factors = [(model, sex) for model in model for sex in sexs ]

counts = [26,13,7,16,12]


source = ColumnDataSource(data=dict(factors=factors, counts=counts))

p = figure(title="HÌNH 2: ĐỒ THỊ GIỚI TÍNH THEO CHIỀU CAO", x_range=FactorRange(*factors),toolbar_location= "right")

p.vbar(x='factors', top='counts', width=0.9, source=source,
       line_color="white",
       fill_color=factor_cmap('factors', palette=["limegreen", "tomato"], factors=sexs, start=1, end=2))

p.add_tools(HoverTool(tooltips=[("model, Sex", "@factors"), ("Count", "@counts")]))

p.y_range.start = 0
p.x_range.range_padding = 0.1 #Khoảng cách giữa đồ thị và trục tung
p.xaxis.major_label_orientation = 1 #độ nghiên của nhãn ở trục x "female và male"

show(p)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('counts', 5), ('factors', 6)
#   <div id="a3c1d5dc-eb53-4b7a-9c1c-3faa5789fcaf" data-root-id="p1053" style="display: contents;"></div>

# %%
df_GENSHIN['WEAPON_TYPE'].value_counts()
# Out:
# WEAPON_TYPE
# Sword       17
# Catalyst    16
# Bow         15
# Claymore    13
# Polearm     13
# Name: count, dtype: int64

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.io import output_notebook
from bokeh.transform import dodge
from bokeh.palettes import Category20

# Dữ liệu từ bài viết của bạn
data = {
    'WEAPON_TYPE': ['Sword', 'Catalyst', 'Bow', 'Claymore', 'Polearm'],
    'COUNTS': [17, 16, 15, 13, 13],
    'COLORS':["pink", "blue", "orange", "green", "lightsalmon"]}

# Tạo ColumnDataSource từ dữ liệu
source = ColumnDataSource(data=data)

# Tạo figure
p = figure(y_range=data['WEAPON_TYPE'], title='Weapon Counts')

# Vẽ biểu đồ HBAR với màu khác nhau cho mỗi cột
p.hbar(y='WEAPON_TYPE', right='COUNTS', height=0.5, source=source, color='COLORS')

# Hiển thị biểu đồ
output_notebook()
show(p)
# Out:
#   <div id="dcc46047-2664-4528-968f-390419012c66" data-root-id="p1100" style="display: contents;"></div>

# %%
from math import pi
from bokeh.colors import groups
from bokeh.layouts import row
from bokeh.plotting import figure, show
from bokeh.transform import cumsum

MALE = {'Sword' : 7, 'Claymore':6, 'Bow': 5, 'Catalyst': 5, 'Polearm': 5}

data = pd.Series(MALE).reset_index(name='value').rename(columns={'index': 'WEAPON_TYPE'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = ["pink", "blue", "orange", "green", "lightsalmon"]


p1 = figure(height=350, title="Đồ thị WEAPON các nhân vật MALE", tooltips="@WEAPON_TYPE: @value", x_range=(-0.5, 1.0))

p1.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='WEAPON_TYPE', source=data)

FEMALE = {'Sword' : 10, 'Claymore':7, 'Bow': 10, 'Catalyst': 11, 'Polearm': 8}

data = pd.Series(FEMALE).reset_index(name='value').rename(columns={'index': 'WEAPON_TYPE'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = ["pink", "blue", "orange", "green", "lightsalmon"]


p2 = figure(height=350, title="Đồ thị WEAPON các nhân vật FEMALE", tooltips="@WEAPON_TYPE: @value", x_range=(-0.5, 1.0))

p2.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='WEAPON_TYPE', source=data)

p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

show(row(p1, p2))
# Out:
#   <div id="dfde8724-1488-4a7d-832e-6614354677fa" data-root-id="p1245" style="display: contents;"></div>

# %%
import plotly.express as px

data=[[3, 1, 4, 5, 0, 1], [1, 2, 4, 4, 0, 1], [0, 4, 2, 3, 0, 2], [1, 3, 1, 3, 0, 2], [0, 2, 3, 2, 0, 0], [2, 2, 2, 2, 1, 2]]
fig = px.imshow(data,
                labels=dict(x="REGION", y="VISION", color="Productivity"),
                x=['Fontaine','Inazuma', 'Liyue','Mondstadt','Snezhnaya', 'Sumeru'],
                y=['Cryo', 'Pyro', 'Electro', 'Anemo', 'Geo', 'Hydro'])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0756176c-7d18-44b9-97d2-9ba8775167a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0756176c-7d18-44b9-97d2-9ba8775167a5")) {                    Plotly.newPlot(                        "0756176c-7d18-44b9-97d2-9ba8775167a5",                        [{"coloraxis":"coloraxis","name":"0","x":["Fontaine","Inazuma","Liyue","Mondstadt","Snezhnaya","Sumeru"],"y":["Cryo","Pyro","Electro","Anemo","Geo","Hydro"],"z":[[3,1,4,5,0,1],[1,2,4,4,0,1],[0,4,2,3,0,2],[1,3,1,3,0,2],[0,2,3,2,0,0],[2,2,2,2,1,2]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"REGION: %{x}\u003cbr\u003eVISION: %{y}\u003cbr\u003eProductivity: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","mar ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Tạo DataFrame mới lưu trữ tần suất xuất hiện
application_counts = df_GENSHIN['ASCENSION'].value_counts().reset_index(name='Count')

# Đặt tên cột
application_counts.columns = ['ASCENSION', 'Count']

# Tạo biểu đồ Scatter
plt.figure(figsize=(10, 6))
plt.scatter(application_counts['ASCENSION'], application_counts['Count'])

# Thêm nhãn cho trục
plt.xlabel('ASCENSION')
plt.ylabel('Tần suất xuất hiện')

# Thêm tiêu đề cho biểu đồ
plt.title('Biểu đồ Scatter cho biến ASCENSION')

# Xoay nhãn x để dễ đọc hơn
plt.xticks(rotation=60)

# Hiển thị biểu đồ
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #**Tính toán HP của nhân vật từ 0_0 đến 90_90 dựa vào HP 90_90 có sẵn**

# %%
#Thêm các cột HP cho nhân vật từ level 0 đến 80
df_GENSHIN['HP_0_0'] = df_GENSHIN['HP_90_90']/14
df_GENSHIN['HP_20_20'] = df_GENSHIN['HP_90_90']/10
df_GENSHIN['HP_40_40'] = df_GENSHIN['HP_90_90']/6
df_GENSHIN['HP_50_50'] = df_GENSHIN['HP_90_90']/5
df_GENSHIN['HP_60_60'] = df_GENSHIN['HP_90_90']/4
df_GENSHIN['HP_70_70'] = df_GENSHIN['HP_90_90']/3
df_GENSHIN['HP_80_80'] = df_GENSHIN['HP_90_90']/2

df_GENSHIN.head(10)
# Out:
#    Unnamed: 0 CHARACTER-NAME  RARITY     REGION   VISION WEAPON_TYPE     SEX  \
# 0           0         Albedo       5  Mondstadt      Geo       Sword    Male
# 1           1      Alhaitham       5     Sumeru   Dendro       Sword    Male
# 2           2           Aloy       5    Unknown     Cryo         Bow  Female
# 3           3          Amber       4  Mondstadt     Pyro         Bow  Female
# 4           4   Arataki Itto       5    Inazuma      Geo    Claymore    Male
# 5           5         Baizhu       5      Liyue   Dendro    Catalyst    Male
# 6           6        Barbara       4  Mondstadt    Hydro    Catalyst  Female
# 7           7         Beidou       4      Liyue  Electro    Claymore  Female
# 8           8        Bennett       4  Mondstadt     Pyro       Sword    Male
# 9           9        Candace       4     Sumeru    Hydro     Polearm  Female
#
#     MODEL   BIRTHDAY       CONSTELLATION  ... LEVEL OF LOVE  \
# 0  Medium 2022-09-13  Princeps Cretaceus  ...          0.60
# 1    Tall 2023-02-11       Vultur Volans  ...          0.76
# 2  Medium 2022-04-04         Nora Fortis  ...          0.10
# 3  Medium 2022-08-10               Lepus  ...          0.40
# 4    Tall 2022-06-01    Taurus Iracundus  ...          0.71
# 5    Tall 2023-04-25           Lagenaria  ...          0.89
# 6  Medium 2022-07-05              Crater  ...          0.58
# 7    Tall 2022-02-14         Victor Mare  ...          0.13
# 8  Medium 2029-02-01      Rota Calamitas  ...          0.95
# 9    Tall 2022-05-03      Sagitta Scutum  ...          0.15
#
#            ASCENSION  PRI SKILL      HP_0_0  HP_20_20     HP_40_40  HP_50_50  \
# 0      Geo DMG Bonus          Q  944.714286    1322.6  2204.333333    2645.2
# 1   Dendro DMG Bonus          E  953.428571    1334.8  2224.666667    2669.6
# 2     Cryo DMG Bonus          Q  778.500000    1089.9  1816.500000    2179.8
# 3                ATK          T  675.785714     946.1  1576.833333    1892.2
# 4          CRIT Rate          Q  918.428571    1285.8  2143.000000    2571.6
# 5                 HP          E  953.428571    1334.8  2224.666667    2669.6
# 6                 HP          E  699.071429     978.7  1631.166667    1957.4
# 7  Electro DMG Bonus          Q  932.142857    1305.0  2175.000000    2610.0
# 8    Energy Recharge          Q  885.500000    1239.7  2066.166667    2479.4
# 9                 HP          Q  776.714286    1087.4  1812.333333    2174.8
#
#   HP_60_60     HP_70_70  HP_80_80
# 0  3306.50  4408.666667    6613.0
# 1  3337.00  4449.333333    6674.0
# 2  2724.75  3633.000000    5449.5
# 3  2365.25  3153.666667    4730.5
# 4  3214.50  4286.000000    6429.0
# 5  3337.00  4449.333333    6674.0
# 6  2446.75  3262.333333    4893.5
# 7  3262.50  4350.000000    6525.0
# 8  3099.25  4132.333333    6198.5
# 9  2718.50  3624.666667    5437.0
#
# [10 rows x 26 columns]

# %%
#Chuyển HP ở level 90 ra cúi hàng
df_GENSHIN.insert(23,"HP_90_90", df_GENSHIN.pop("HP_90_90"))
df_GENSHIN.head(10)
# Out:
#    Unnamed: 0 CHARACTER-NAME  RARITY     REGION   VISION WEAPON_TYPE     SEX  \
# 0           0         Albedo       5  Mondstadt      Geo       Sword    Male
# 1           1      Alhaitham       5     Sumeru   Dendro       Sword    Male
# 2           2           Aloy       5    Unknown     Cryo         Bow  Female
# 3           3          Amber       4  Mondstadt     Pyro         Bow  Female
# 4           4   Arataki Itto       5    Inazuma      Geo    Claymore    Male
# 5           5         Baizhu       5      Liyue   Dendro    Catalyst    Male
# 6           6        Barbara       4  Mondstadt    Hydro    Catalyst  Female
# 7           7         Beidou       4      Liyue  Electro    Claymore  Female
# 8           8        Bennett       4  Mondstadt     Pyro       Sword    Male
# 9           9        Candace       4     Sumeru    Hydro     Polearm  Female
#
#     MODEL   BIRTHDAY       CONSTELLATION  ...          ASCENSION PRI SKILL  \
# 0  Medium 2022-09-13  Princeps Cretaceus  ...      Geo DMG Bonus         Q
# 1    Tall 2023-02-11       Vultur Volans  ...   Dendro DMG Bonus         E
# 2  Medium 2022-04-04         Nora Fortis  ...     Cryo DMG Bonus         Q
# 3  Medium 2022-08-10               Lepus  ...                ATK         T
# 4    Tall 2022-06-01    Taurus Iracundus  ...          CRIT Rate         Q
# 5    Tall 2023-04-25           Lagenaria  ...                 HP         E
# 6  Medium 2022-07-05              Crater  ...                 HP         E
# 7    Tall 2022-02-14         Victor Mare  ...  Electro DMG Bonus         Q
# 8  Medium 2029-02-01      Rota Calamitas  ...    Energy Recharge         Q
# 9    Tall 2022-05-03      Sagitta Scutum  ...                 HP         Q
#
#        HP_0_0  HP_20_20     HP_40_40  HP_50_50 HP_60_60 HP_90_90     HP_70_70  \
# 0  944.714286    1322.6  2204.333333    2645.2  3306.50    13226  4408.666667
# 1  953.428571    1334.8  2224.666667    2669.6  3337.00    13348  4449.333333
# 2  778.500000    1089.9  1816.500000    2179.8  2724.75    10899  3633.000000
# 3  675.785714     946.1  1576.833333    1892.2  2365.25     9461  3153.666667
# 4  918.428571    1285.8  2143.000000    2571.6  3214.50    12858  4286.000000
# 5  953.428571    1334.8  2224.666667    2669.6  3337.00    13348  4449.333333
# 6  699.071429     978.7  1631.166667    1957.4  2446.75     9787  3262.333333
# 7  932.142857    1305.0  2175.000000    2610.0  3262.50    13050  4350.000000
# 8  885.500000    1239.7  2066.166667    2479.4  3099.25    12397  4132.333333
# 9  776.714286    1087.4  1812.333333    2174.8  2718.50    10874  3624.666667
#
#    HP_80_80
# 0    6613.0
# 1    6674.0
# 2    5449.5
# 3    4730.5
# 4    6429.0
# 5    6674.0
# 6    4893.5
# 7    6525.0
# 8    6198.5
# 9    5437.0
#
# [10 rows x 26 columns]

# %%
#SAO SÁNH HP, DEF, ATK CỦA CÁC NHÂN VẬT
from bokeh.layouts import column
from bokeh.models.tools import HoverTool
p1 = figure(x_range=df_GENSHIN['CHARACTER-NAME'], height=300, width = 1160, title="HP_90_90 nhân vật")
p1.line(x='CHARACTER-NAME', y='HP_90_90', source=df_GENSHIN, line_width=2, line_color="darkturquoise")
p1.add_tools(HoverTool(tooltips=[("HP_90_90", "@{HP_90_90}")]))


p1.xaxis.major_label_orientation = 1

p2 = figure(x_range=df_GENSHIN['CHARACTER-NAME'], height=300, width = 1160, title="DEF_90_90 nhân vật")
p2.line(x='CHARACTER-NAME', y='DEF_90_90', source=df_GENSHIN, line_width=2, line_color="burlywood")
p2.add_tools(HoverTool(tooltips=[("DEF_90_90", "@{DEF_90_90}")]))

p2.xaxis.major_label_orientation = 1

p3 = figure(x_range=df_GENSHIN['CHARACTER-NAME'], height=300, width = 1160, title="ATK_90_90 nhân vật")
p3.line(x='CHARACTER-NAME', y='ATK_90_90', source=df_GENSHIN, line_width=2, line_color="orangered")
p3.add_tools(HoverTool(tooltips=[("ATK_90_90", "@{ATK_90_90}")]))

p3.xaxis.major_label_orientation = 1
# Hiển thị đồ thị
show(column(p1,p2,p3))
# Out:
#   <div id="a7358fde-b50c-4d2a-a31a-2913c2ad1625" data-root-id="p1393" style="display: contents;"></div>

# %%
from bokeh.io import output_file, show # dùng để chỉ định tên file HTML mà đồ thị sẽ được lưu vào khi xuất. Hàm show dùng để hiển thị đồ thị trong trình duyệt web hoặc lưu nó vào file
from bokeh.models import ColumnDataSource, FactorRange # Câu lệnh này nhập ColumnDataSource, một đối tượng cung cấp dữ liệu cho các glyphs trong Bokeh, và FactorRange, dùng để tạo ra phạm vi cho các biến phân loại (categorical variables) trên trục đồ thị.
from bokeh.transform import factor_cmap #bảng màu

HP = [("HP_0_0"), ("HP_20_20"), ("HP_40_40"), ("HP_50_50"), ("HP_60_60"), ("HP_70_70"), ("HP_80_80"), ("HP_90_90")]

Amber = [778.5,	1089.9, 1576.8,	1892.2,	2365.3,	3153.7,	4730.5,	9461]
Diluc = [927.2,	1298.1,	2163.5,	2596.2,	3245.3,	4327.0,	6490.5,	12981]

p = figure(title="ĐỒ THỊ HP của Amber (4*) và Diluc (5*)", x_range = FactorRange(*HP),toolbar_location= "right")

p.line(x = HP, y = Amber, legend_label="Amber", color="blue", line_width=2)
p.line(x = HP, y = Diluc, legend_label="Diluc", color="red", line_width=2)

p.y_range.start = 0
p.x_range.range_padding = 0.1 #Khoảng cách giữa đồ thị và trục tung
p.xaxis.major_label_orientation = 1 #độ nghiên của nhãn ở trục x "female và male"

show(p)
# Out:
#   <div id="ba205566-b26c-4972-9319-aedd4fa9fc92" data-root-id="p1446" style="display: contents;"></div>

# %%
from bokeh.layouts import column
from bokeh.models.tools import HoverTool
p1 = figure(x_range=df_GENSHIN['CHARACTER-NAME'], height=300, width = 1160, title="Mức độ sử dụng nhân vật")
p1.line(x='CHARACTER-NAME', y='LEVEL OF USE', source=df_GENSHIN, line_width=2, line_color="aqua")
p1.add_tools(HoverTool(tooltips=[("LEVEL OF USE", "@{LEVEL OF USE}")]))


p1.xaxis.major_label_orientation = 1

p2 = figure(x_range=df_GENSHIN['CHARACTER-NAME'], height=300, width = 1160, title="Mức độ yêu thích nhân vật")
p2.line(x='CHARACTER-NAME', y='LEVEL OF LOVE', source=df_GENSHIN, line_width=2, line_color="brown")
p2.add_tools(HoverTool(tooltips=[("LEVEL OF LOVE", "@{LEVEL OF LOVE}")]))

p2.xaxis.major_label_orientation = 1
# Hiển thị đồ thị
show(column(p1,p2))
# Out:
#   <div id="e3d25ef5-3215-4c25-8b91-f0a827f1a21d" data-root-id="p1594" style="display: contents;"></div>

# %%
df_GENSHIN["Crit dame"] = df_GENSHIN.apply(lambda row: row['ATK_90_90'] * 0.7 if row['ATK_90_90'] > 300 else row['ATK_90_90'] * 0.4, axis=1)
df_GENSHIN["Crit rate"] = df_GENSHIN.apply(lambda row: row['Crit dame']/3 if row['ATK_90_90'] > 300 else row['Crit dame']/2, axis=1)

df_GENSHIN.tail()
# Out:
#     Unnamed: 0 CHARACTER-NAME  RARITY   REGION  VISION WEAPON_TYPE     SEX  \
# 69          69         Yaoyao       4    Liyue  Dendro     Polearm  Female
# 70          70          Yelan       5    Liyue   Hydro         Bow  Female
# 71          71        Yoimiya       5  Inazuma    Pyro         Bow  Female
# 72          72        Yun Jin       4    Liyue     Geo     Polearm  Female
# 73          73        Zhongli       5    Liyue     Geo     Polearm    Male
#
#      MODEL   BIRTHDAY      CONSTELLATION  ...       HP_0_0 HP_20_20  \
# 69   Short 2023-03-06          Osmanthus  ...   877.714286   1228.8
# 70    Tall 2022-04-20  Umbrabilis Orchis  ...  1032.142857   1445.0
# 71  Medium 2022-06-21  Carassius Auratus  ...   726.000000   1016.4
# 72  Medium 2022-05-21      Opera Grandis  ...   761.214286   1065.7
# 73    Tall 2022-12-31          Lapis Dei  ...  1049.642857   1469.5
#
#        HP_40_40  HP_50_50  HP_60_60  HP_90_90     HP_70_70 HP_80_80  \
# 69  2048.000000    2457.6   3072.00     12288  4096.000000   6144.0
# 70  2408.333333    2890.0   3612.50     14450  4816.666667   7225.0
# 71  1694.000000    2032.8   2541.00     10164  3388.000000   5082.0
# 72  1776.166667    2131.4   2664.25     10657  3552.333333   5328.5
# 73  2449.166667    2939.0   3673.75     14695  4898.333333   7347.5
#
#     Crit dame  Crit rate
# 69       84.8  42.400000
# 70       97.6  48.800000
# 71      226.1  75.366667
# 72       76.4  38.200000
# 73      100.4  50.200000
#
# [5 rows x 28 columns]

# %%
#Tải dataframe xuống
df_GENSHIN.to_excel('GENSHIN_08.xlsx', index=False)

# %%
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool

p1 = figure(x_range=df_GENSHIN['CHARACTER-NAME'], height=300, width = 1160, title="Mức sát thương bạo (%)")
p1.line(x='CHARACTER-NAME', y='Crit dame', source=df_GENSHIN, line_width=2, line_color="deepskyblue")
p1.add_tools(HoverTool(tooltips=[("Crit dame", "@{Crit dame}")]))


p1.xaxis.major_label_orientation = 1

p2 = figure(x_range=df_GENSHIN['CHARACTER-NAME'], height=300, width = 1160, title="Mức tỷ lệ bạo (%)")
p2.line(x='CHARACTER-NAME', y='Crit rate', source=df_GENSHIN, line_width=2, line_color="red")
p2.add_tools(HoverTool(tooltips=[("Crit rate", "@{Crit rate}")]))

p2.xaxis.major_label_orientation = 1
# Hiển thị đồ thị
show(column(p1,p2))
# Out:
#   <div id="b3e59b7c-f9a0-4e91-a52c-d51f89b0bcb9" data-root-id="p1723" style="display: contents;"></div>

# %%
url = 'https://docs.google.com/spreadsheets/d/1IGxLeheokwm1-JSavbUUkBUS-Ucrx6Ys/edit?usp=drive_link&ouid=111930618054542411595&rtpof=true&sd=true'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]
df_PUNT = pd.read_excel(url)
df_PUNT
# Out:
#                      Tên              VISION VISION 2 VISION 3  \
# 0               Kết Tinh                 Geo        x      NaN
# 1             Khuếch Tán               Anemo        x      NaN
# 2              Đá bền bỉ                 Geo      Geo      NaN
# 3   Ngọn lửa nhiệt thành                Pyro     Pyro      NaN
# 4         Nước nhẹ nhàng               Hydro    Hydro      NaN
# 5               Gió mạnh               Anemo    Anemo      NaN
# 6           Điện cao thế             Electro  Electro      NaN
# 7            Băng tan vỡ                Cryo     Cryo      NaN
# 8           Thảo lan tỏa              Dendro   Dendro      NaN
# 9             Tán bảo vệ  4 nguyên tố bất kì      NaN      NaN
# 10            Nhiễm Điện             Electro    Hydro      NaN
# 11               Quá tải             Electro     Pyro      NaN
# 12             Đông cứng                Cryo    Hydro      NaN
# 13              Tan chảy                Cryo     Pyro      NaN
# 14              Siêu Dẫn                Cryo  Electro      NaN
# 15               Bốc hơi               Hydro     Pyro      NaN
# 16              Đốt chấy              Dendro     Pyro      NaN
# 17                Nở Hoa              Dendro    Hydro      NaN
# 18           Siêu Nở Hoa              Dendro    Hydro  Electro
# 19               Nảy nầm              Dendro    Hydro     Pyro
# 20               Xúc Tác              Dendro  Electro      NaN
# 21            Kích Thích              Dendro  Electro  Electro
# 22               Lan tỏa              Dendro  Electro   Dendro
#
#                                                 Mô tả
# 0   Tạo ra một kết tỉnh có thuộc tính nguyên tổ. K...
# 1   Gây thêm sát thương nguyên tố và hiệu ứng lan ...
# 2   Tăng khả năng chống gián đoạn. Khi được bảo vệ...
# 3   Bị ảnh hưởng bởi nguyên tố Băng ít hơn 40%. Tă...
# 4   Bị ảnh hưởng bởi nguyên tố Pyro ít hơn 40%. Tă...
# 5   Giảm 15% tiêu hao thể lực. Tăng 10% tốc độ di ...
# 6   Bị ảnh hưởng bởi nguyên tố Thủy ít hơn 40%. Si...
# 7   Bị ảnh hưởng bởi nguyên tố Lôi ít hơn 40%. Tăn...
# 8   Sau khi kích hoạt các phản ứng Đốt cháy, Xúc t...
# 9   Tăng thêm 15% kháng tất cả các nguyên tố còn lại.
# 10      Ưu đãi sát thương hệ Lôi tăng theo thời gian.
# 11  Gây sát thương lửa lan lên các kẻ địch xung qu...
# 12                                 Đóng băng mục tiêu
# 13                               Gây thêm sát thương.
# 14  Gây sát thương băng lan và giảm 50% Kháng vật ...
# 15                               Gây thêm sát thương.
# 16                  Gây sát thương Lửa theo thời gian
# 17  Phản ứng nguyên tố mới khiến Hạt Nở rơi trên m...
# 18  Tác động nguyên tố Lôi lên Hạt Nở sẽ gây sát t...
# 19  Tác động nguyên tố Pyro lên Hạt Nở sẽ gây ra m...
# 20                     Đồng mình sẽ tích nộ nhanh hơn
# 21  Tác động nguyên tố Lôi lên phản ứng Xúc Tác sẽ...
# 22  Tác động nguyên tố Thảo lên phản ứng Xúc Tác s...

# %%
import numpy as np
#Nhập tên nhân vật muốn phân tích các phản ứng có thể xảy ra
a = input("Tên Nhân Vật: ")
vision = df_GENSHIN[df_GENSHIN['CHARACTER-NAME']== a]['VISION']
vision = np.array(vision)[0]
print(vision)
#Lọc ra những phản ứng có thể xảy ra
df_c1 = df_PUNT[df_PUNT['VISION']== vision]
df_c2 = df_PUNT[df_PUNT['VISION 2']== vision]
df_c3 = df_PUNT[df_PUNT['VISION 3']== vision]

df_merged = pd.concat([df_c1, df_c2, df_c3], axis=0) #Gộp 3 df trên thành 1
df_merged.drop_duplicates(inplace=True)   #Xóa những dòng trùng lặp
print(df_merged.to_string(index=False, max_cols=10, justify = "center")) #max_cols: Giúp thêm dòng -> ko bị tách bảng, justify: Định dạng nhãn
# Out:
# Tên Nhân Vật: Diluc
# Pyro
#         Tên           VISION VISION 2 VISION 3                                                  Mô tả
# Ngọn lửa nhiệt thành    Pyro   Pyro      NaN                                             Bị ảnh hưởng bởi nguyên tố Băng ít hơn 40%. Tăng 25% tấn công.
#              Quá tải Electro   Pyro      NaN                                                         Gây sát thương lửa lan lên các kẻ địch xung quanh.
#             Tan chảy    Cryo   Pyro      NaN                                                                                       Gây thêm sát thương.
#              Bốc hơi   Hydro   Pyro      NaN                                                                                       Gây thêm sát thương.
#             Đốt chấy  Dendro   Pyro      NaN                                                                          Gây sát thương Lửa theo thời gian
#              Nảy nầm  Dendro  Hydro     Pyro   Tác động nguyên tố Pyro lên Hạt Nở sẽ gây ra một vụ nổ nhỏ gây sát thương nguyên tổ Pyro xung quanh hạt.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = df_GENSHIN
df['HP_90_90'] = df_GENSHIN['HP_90_90']/49
df['DEF_90_90'] = df_GENSHIN['DEF_90_90']/3
df['Crit rate'] = df_GENSHIN['Crit rate']*3
df
# Out:
#     Unnamed: 0 CHARACTER-NAME  RARITY     REGION  VISION WEAPON_TYPE     SEX  \
# 0            0         Albedo       5  Mondstadt     Geo       Sword    Male
# 1            1      Alhaitham       5     Sumeru  Dendro       Sword    Male
# 2            2           Aloy       5    Unknown    Cryo         Bow  Female
# 3            3          Amber       4  Mondstadt    Pyro         Bow  Female
# 4            4   Arataki Itto       5    Inazuma     Geo    Claymore    Male
# ..         ...            ...     ...        ...     ...         ...     ...
# 69          69         Yaoyao       4      Liyue  Dendro     Polearm  Female
# 70          70          Yelan       5      Liyue   Hydro         Bow  Female
# 71          71        Yoimiya       5    Inazuma    Pyro         Bow  Female
# 72          72        Yun Jin       4      Liyue     Geo     Polearm  Female
# 73          73        Zhongli       5      Liyue     Geo     Polearm    Male
#
#      MODEL   BIRTHDAY       CONSTELLATION  ...       HP_0_0 HP_20_20  \
# 0   Medium 2022-09-13  Princeps Cretaceus  ...   944.714286   1322.6
# 1     Tall 2023-02-11       Vultur Volans  ...   953.428571   1334.8
# 2   Medium 2022-04-04         Nora Fortis  ...   778.500000   1089.9
# 3   Medium 2022-08-10               Lepus  ...   675.785714    946.1
# 4     Tall 2022-06-01    Taurus Iracundus  ...   918.428571   1285.8
# ..     ...        ...                 ...  ...          ...      ...
# 69   Short 2023-03-06           Osmanthus  ...   877.714286   1228.8
# 70    Tall 2022-04-20   Umbrabilis Orchis  ...  1032.142857   1445.0
# 71  Medium 2022-06-21   Carassius Auratus  ...   726.000000   1016.4
# 72  Medium 2022-05-21       Opera Grandis  ...   761.214286   1065.7
# 73    Tall 2022-12-31           Lapis Dei  ...  1049.642857   1469.5
#
#        HP_40_40  HP_50_50  HP_60_60    HP_90_90     HP_70_70 HP_80_80  \
# 0   2204.333333    2645.2   3306.50  269.918367  4408.666667   6613.0
# 1   2224.666667    2669.6   3337.00  272.408163  4449.333333   6674.0
# 2   1816.500000    2179.8   2724.75  222.428571  3633.000000   5449.5
# 3   1576.833333    1892.2   2365.25  193.081633  3153.666667   4730.5
# 4   2143.000000    2571.6   3214.50  262.408163  4286.000000   6429.0
# ..          ...       ...       ...         ...          ...      ...
# 69  2048.000000    2457.6   3072.00  250.775510  4096.000000   6144.0
# 70  2408.333333    2890.0   3612.50  294.897959  4816.666667   7225.0
# 71  1694.000000    2032.8   2541.00  207.428571  3388.000000   5082.0
# 72  1776.166667    2131.4   2664.25  217.489796  3552.333333   5328.5
# 73  2449.166667    2939.0   3673.75  299.897959  4898.333333   7347.5
#
#     Crit dame  Crit rate
# 0       100.4      150.6
# 1       261.1      261.1
# 2        93.6      140.4
# 3        89.2      133.8
# 4       228.9      228.9
# ..        ...        ...
# 69       84.8      127.2
# 70       97.6      146.4
# 71      226.1      226.1
# 72       76.4      114.6
# 73      100.4      150.6
#
# [74 rows x 28 columns]

# %%
ten_nhan_vat1 = input("Nhập tên nhân vật thứ nhất: ")
ten_nhan_vat2 = input("Nhập tên nhân vật thứ hai: ")

nhan_vat1 = df[df['CHARACTER-NAME'] == ten_nhan_vat1]
nhan_vat2 = df[df['CHARACTER-NAME'] == ten_nhan_vat2]

if nhan_vat1.empty or nhan_vat2.empty:
    print("Không tìm thấy thông tin cho ít nhất một trong hai nhân vật.")
else:
    # Lựa chọn 5 cột để vẽ đồ thị radar spider
    columns_to_plot = ['HP_90_90', 'ATK_90_90', 'DEF_90_90', 'Crit dame', 'Crit rate']
    nhan_vat1_selected = nhan_vat1[columns_to_plot]
    nhan_vat2_selected = nhan_vat2[columns_to_plot]

    # Tạo đồ thị radar spider cho cả hai nhân vật
    categories = list(nhan_vat1_selected.columns)
    N = len(categories)

    angles = [n / float(N) * 2 * np.pi for n in range(N)]
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'polar': True})
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories)
    ax.set_yticklabels([])

    values1 = nhan_vat1_selected.values.flatten().tolist()
    values1 += values1[:1]
    ax.plot(angles, values1, label=ten_nhan_vat1)
    ax.fill(angles, values1, alpha=0.25)

    values2 = nhan_vat2_selected.values.flatten().tolist()
    values2 += values2[:1]
    ax.plot(angles, values2, label=ten_nhan_vat2)
    ax.fill(angles, values2, alpha=0.25)

    plt.legend(loc='upper right')
    plt.title(f"Biểu đồ Radar Spider so sánh chỉ số của {ten_nhan_vat1} và {ten_nhan_vat2}")
    plt.show()
# Out:
# Nhập tên nhân vật thứ nhất: Eula
# Nhập tên nhân vật thứ hai: Zhongli
